# %% [markdown]
# # Filtrado de datos atípicos
# ## Características del filtrado de outliers
# Para el filtrado de outliers se toma como base el volúmen y el rendimiento obtenidos a partit de la serie de datos del NASDAQ.

# %%
import numpy as np; import matplotlib.pyplot as  plt; import pandas as pd
from scipy.spatial.distance import mahalanobis as mhl
plt.rcParams.update({'font.size': 11})

serie_price_original = pd.read_csv('datos.csv')
serie_price = serie_price_original.copy()
serie_price_original = serie_price_original[1:]
serie_price['Volume'] = serie_price['Volume']/1000000000 #Volumen en miles de millones
serie_price['rdto'] = (serie_price['Close'] / serie_price['Close'].shift(1) - 1) * 100 #Base 100
serie_limpia = serie_price[['Volume', 'rdto']][1:]
serie_limpia.reset_index(drop = True)
serie_price_original['rdto'] = serie_price['rdto']
serie_price_original.reset_index(drop = True);

# %%
def covMat(df, lam):
    


## Función para filtrado de outliers utilizando la distancia de Mahalanobis
def outliers (df, lam):
  cov = df.cov() + lam* np.eye(2)
  inv_cov = np.linalg.pinv(cov)
  print('Condición ', np.linalg.cond(cov))
  median = [np.median(df['Volume']), np.median(df['rdto'])]
  mahal_distances = []
  for i in range(len(df)):
    mahal_distances.append(mhl(median, list(df.iloc[i]), inv_cov))

  return mahal_distances;

mahal_serie_limpia = outliers(serie_limpia, lam = 0.01)
# Out:
# Condición  6.76607778841538

# %%
limit = np.percentile(mahal_serie_limpia, 90)
outliers_datos = serie_limpia[mahal_serie_limpia > limit]

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.scatter(serie_limpia['Volume'], serie_limpia['rdto'], zorder = 10)
plt.xlabel('Volúmen'); plt.ylabel('Rendimiento')
plt.minorticks_on(); plt.grid(which='major', zorder=0); plt.grid(which='minor', alpha=0.3)
plt.subplot(1,2,2)
plt.scatter(serie_limpia['Volume'], serie_limpia['rdto'], zorder=10)
plt.scatter(outliers_datos['Volume'], outliers_datos['rdto'], c = 'r', zorder=10)
plt.plot(np.median(serie_limpia['Volume']), np.median(serie_limpia['rdto']), 'ko', zorder=10)
plt.xlabel('Volúmen'); plt.ylabel('Rendimiento')
plt.minorticks_on(); plt.grid(which='major', zorder=0); plt.grid(which='minor', alpha=0.3)

plt.legend(['Datos', 'Outliers', 'Mediana'])

plt.savefig('test.png',bbox_inches='tight')

# %%
dataset_limpio = serie_price_original[mahal_serie_limpia < limit]
dataset_limpio.set_index('Date', inplace = True)
dataset_limpio.to_csv('dataset_limpio_90.csv')
